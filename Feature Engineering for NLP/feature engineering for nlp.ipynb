# %%
import pandas as pd
from textatistic import Textatistic
import nltk
from nltk.tokenize import sent_tokenize
import spacy
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
text = """
﻿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business


Ride-sharing firm Uber is facing a criminal investigation by the US government.


The scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.


The software, called "greyball", helped it identify officials seeking to stop the service running.


A spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.


It is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.


Bookings blocked


In those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally. Greyball worked out who the officials were and blocked them from booking rides with the company's drivers.


In a letter sent last week to transport regulators in Portland, Uber said it used the greyball software "exceedingly sparingly" in the city and had not used it since April 2015 when it was granted permission to operate.


Uber's use of the software was revealed by the New York Times earlier this year. Uber defended its use in a blog saying the software helped it work out if a ride request was legitimate. It helped Uber limit fraud and protect drivers from harm, it added.


It is not clear what sanctions Uber will face if the investigation finds that it did act illegally.


The criminal inquiry comes at a difficult time for Uber which has faced criticism on many fronts. It is currently fighting a lawsuit from Google-backed self-driving car firm Waymo.Despite all the current hype about the rise of voice-assisted devices using Alexa and Siri, linguistics researcher Rachael Tatman found people complaining on social media that the technology still doesn’t understand them.


That’s especially true with regional accents of people who live in the South or are from countries like New Zealand, Tatman said last week during a conference in San Francisco.


“So this is the whatever the opposite of delight is as a user experience,” she said. “People are so upset that they’re going on Twitter and yelling about it.”


Tatman, a doctoral candidate with the University of Washington’s linguistics department, was one of the speakers at a two-day Virtual Assistant Summit, which wrapped up Friday at the Park Central Hotel. The conference, and an adjacent Deep Learning Summit, drew about 600 people representing companies that are working on advancing artificial intelligence, machine learning and robotics.


Lots of people are already using those technologies in programs like Apple’s Siri. They are moving beyond mobile phones and into smart-home devices like Amazon’s Echo. Other fast-changing technologies include artificial intelligence and consumer robotics, especially with self-driving cars on the horizon.


But there’s still work to be done in each of those areas, speakers said. For example, artificial speech recognition technologies still fall short of the way humans can quickly learn and discern speech patterns from each other in “as little as two sentences,” Tatman said.


But that’s because humans take into account other factors, such as the gender of person talking or whether they’ve previously met someone from the the same region, she said.


Tatman examined YouTube’s automatic captioning program, which can translate spoken words into text in several languages. She found that more errors showed up in translations from speakers who had a Southern accent than from people who lived in California.


“The South is the largest demographic region in the United States,” she said. “If you’re using a voice-based virtual assistant and you can’t deal with Southern speech, you’re going to have problems reaching this market.”


For businesses trying to serve those markets, speech recognition technology could be crucial to future revenue, said Stephen Scarr, CEO of search services Info.com and eContext.


With 20 percent of all searches already done through voice, “this is really important, this is No. 1 on your radar,” Scarr told the developers.


As an example of the challenge, a recent YouTube video showed Amazon’s Alexa misunderstanding a young boy’s request to play a song, and instead offering to play an audio porn channel.


The conference touched on more than just speech technologies. Alonso Martinez, a Pixar Animation Studios technical director, said robot developers could take cues from the ways animators create deep emotional connections with audiences.


“When you’re thinking about a robot, don’t think about it as a generic, faceless thing,” said Martinez, who developed characters in “Up” and “Inside Out,” two of the Emeryville company’s hit movies. “You need to ask what makes them admirable. What are the values that they have that I wish that I had in myself?”


Elena Corina Grigore of Yale University’s Social Robotics Lab said robots now used in manufacturing can work by themselves because they are easily trained to perform specialized, repetitive tasks. But robots are not well-equipped to collaborate with humans, she said.


That’s slowly changing with advances in artificial intelligence. As an example, Grigore played a video of a robot trained to help a person with what can be a complex and maddening task — assembling a chair from Ikea.


Still, Grigore said, “We’re not getting replaced by robots anytime soon. We’re not at a point where the robots have the intelligence or the physical capabilities necessary to perform all of these actions on their own. Anything that is related to common sense or creativity or types of thinking that require on-the-spot flexibility in a dynamic and changing environment is still very hard to achieve for us.”


Benny Evangelista is a San Francisco Chronicle staff writer. Email: bevangelista@sfchronicle.com Twitter: @ChronicleBenny The French electorate heads to the polls in the second round of presidential elections on May 7, followed by votes in Britain and Germany in the coming months. Computer scientists, tech giants and start-ups are using sophisticated algorithms and reams of online data to quickly — and automatically — spot fake news faster than traditional fact-checking groups can.


Advertisement Continue reading the main story


The goal, experts say, is to expand these digital tools across Europe, so the region can counter the fake news that caused so much confusion and anger during the United States presidential election in November, when outright false reports routinely spread like wildfire on Facebook and Twitter.


“Algorithms will have to do a lot of the heavy lifting when it comes to fighting misinformation,” said Claire Wardle, head of strategy and research at First Draft News, a nonprofit organization that has teamed up with tech companies and newsrooms to debunk fake reports about elections in the United States and Europe. “It’s impossible to do all of this by hand.”


Researchers have tried to learn from the United States’ run-in with fake news, but the problem in Europe has mutated, experts say, making it impossible to merely replicate American responses to the issue.


Advertisement Continue reading the main story


European countries have different languages, and their media markets are smaller than those in the United States. That means groups that set up fake news sites in the United States, seeking to profit from online advertising when false claims were shared on social media, are less prevalent in Europe.


Advertisement Continue reading the main story


So far, outright fake news stories have been relatively rare. Instead, false reports have more often come from Europeans on social media taking real news out of context, as well as from fake claims spread by state-backed groups like Sputnik, the Russian news organization.


Advertisement Continue reading the main story


But with fake news already swirling around Europe’s forthcoming elections, analysts also worry that technology on its own may not be enough to combat the threat.


“There’s an increased amount of misinformation out there,” said Janis Sarts, director of the NATO Strategic Communications Center of Excellence, a think tank in Riga, Latvia, that will hold a hackathon with local coders in May to find potential tech solutions to this trend. “State-based actors have been trying to amplify specific views to bring them into the mainstream.”


Calls for combating fake news have focused on some of the biggest online players, including American giants like Facebook and Google.


Interested in all things tech? The daily Bits newsletter will keep you updated on the latest from Silicon Valley and the technology industry, plus exclusive analysis from our reporters and editors. Please verify you're not a robot by clicking the box. Invalid email address. Please re-enter. You must select a newsletter to subscribe to. Sign Up Receive occasional updates and special offers for The New York Times's products and services. Thank you for subscribing. An error has occurred. Please try again later. View all New York Times newsletters.


After criticism of its role in spreading false reports during the United States elections, Facebook introduced a fact-checking tool ahead of the Dutch elections in March and the first round of the French presidential election on April 23. It also removed 30,000 accounts in France that had shared fake news, a small fraction of the approximately 33 million Facebook users in the country.


Photo


Not everyone, though, has embraced Facebook’s response.


Most German publishers, for instance, have so far balked at participating in the company’s fact-checking efforts, saying it is the responsibility of the social network, not them, to debunk such claims. German lawmakers are mulling potential hefty fines against tech companies if they do not clamp down on fake news and online hate speech.


Advertisement Continue reading the main story


Since last year, Google also has funded almost 20 European projects aimed at fact-checking potentially false reports. That includes its support for two British groups looking to use artificial intelligence to automatically fact-check online claims ahead of the country’s June 8 parliamentary election.


Advertisement Continue reading the main story


It similarly has teamed up with French newsrooms to create digital tools, including ways to track trending topics during that country’s election.


David Dieudonné, head of the company’s news lab in France, said the project had debunked 43 reports since February (arguably a relatively small figure), including claims that Saudi Arabia was funding the campaign of Emmanuel Macron, the leading candidate.


Advertisement Continue reading the main story


“We’re trying something new,” Mr. Dieudonné said. “There’s no easy answer for this complicated issue.”


Not all potential solutions, though, are being driven by Silicon Valley’s big beasts.


David Chavalarias, a French academic, has created a digital tool that has analyzed more than 80 million Twitter messages about the French election, helping journalists and fact-checkers to quickly review claims that are spread on the social network.


Advertisement Continue reading the main story


After the presidential election in the United States last year, Dean Pomerleau, a computer scientist at Carnegie Mellon University in Pittsburgh, also challenged his followers on Twitter to come up with an algorithm that could distinguish fake claims from real news.


Advertisement Continue reading the main story


Working with Delip Rao, a former Google researcher, he offered a $2,000 prize to anyone who could meet his requirements. By early this year, more than 100 teams from around the world had signed on to Mr. Pomerleau’s Fake News Challenge.


Using a database of verified articles and their artificial intelligence expertise, rival groups — a combination of college teams, independent programmers and groups from existing tech companies — already have been able to accurately predict the veracity of certain claims almost 90 percent of the time, Mr. Pomerleau said. He hopes that figure will rise to the mid-90s before his challenge ends in June.


Advertisement Continue reading the main story


“This is just Round 1 of what we want to do,” said Mr. Pomerleau, who expects the teams to share their work with fact-checking groups worldwide. “Next, we want to move toward multimedia content like videos.”


Advertisement Continue reading the main story


In the rush to find solutions to fake news, some within the industry are taking a decidedly more low-tech approach.


Jimmy Wales, the founder of Wikipedia, recently started a crowdfunding campaign to create a news organization that would combine professional journalists with digital volunteers, who would contribute to reports in a way similar to how articles are created on Wikipedia.


Part fact-checking site, part traditional newsroom, the project — called Wikitribune — was inspired by the effect of misinformation on the United States presidential election. Mr. Wales said his project would choose subject areas based on the interests of the community of volunteers and paying subscribers to the service, relying more on traditional reporting techniques than high-tech wizardry.


Advertisement Continue reading the main story


“The real impetus for this was fake news,” he said. “We want people to get behind topics, and then we’ll hire staff to cover them.” Ruchir Sharma, chief global strategist at Morgan Stanley Investment Management, is the author of “The Rise and Fall of Nations: Forces of Change in the The Post-Crisis World,” from which this essay is adapted.






A robot collects dishes to be cleaned at Chilli Padi Nonya Cafe in Singapore. (REUTERS/Edgar Su)


The United Nations forecasts that the global population will rise from 7.3 billion to nearly 10 billion by 2050, a big number that often prompts warnings about overpopulation. Some have come from neo-Malthusians, who fear that population growth will outstrip the food supply, leaving a hungry planet. Others appear in the tirades of anti-immigrant populists, invoking the specter of a rising tide of humanity as cause to slam borders shut. Still others inspire a chorus of neo-Luddites, who fear that the “rise of the robots” is rapidly making human workers obsolete, a threat all the more alarming if the human population is exploding.


Before long, though, we’re more likely to treasure robots than to revile them. They may be the one thing that can protect the global economy from the dangers that lie ahead.


An increase of 2.5 billion people may sound catastrophic. But what matters for economic growth is not the number of people but the rate of population growth. Since its peak in the 1960s, that rate has slumped by almost half to just 1 percent, and the U.N. forecast assumes that this slowdown will continue. Women are having fewer children, so fewer people are entering the working ages between 15 and 64, and labor-force growth is poised to decline from Chile to China. At the same time, owing to rapid advances in health care and medicine, people are living longer , and most of the coming global population increase will be among the retirement crowd. These trends are toxic for economic growth, and boosting the number of robots may be the easiest answer for many countries.


One simple way to estimate how fast an economy can grow is by adding working-age population growth and productivity growth: If the number of workers and output per worker are both increasing by 1 percent a year, then economic output should rise by roughly 2 percent. Over the past decade, both sides of that equation have declined dramatically across the world. In the United States, productivity growth has fallen by almost half from its postwar average, but growth in the labor force has slid even faster, dropping by two-thirds to an average pace of 0.5 percent, according to calculations performed for my book. Though many explanations have been offered for the slow recovery from the global financial crisis of 2008, the clearest answer may be aging populations. Something will have to fill the void left by, say, retiring farmers, and particularly at a time of rising hostility to immigrants, it is likely to be farmbots.


It may not be long before economists are worrying about a global shortage of robots. In many industrial countries, from Germany to Japan to South Korea, growth in the working-age population has already peaked, acting as a drag on the economy. Widely overlooked, however, is the fact that the population-growth slowdown is unfolding even faster in the emerging world, according to my research.


Consider the turning point that China hit last year. For the first time since records began in the 1950s, its working-age population growth was negative. As a result, China’s labor force is expected to lose 1 million workers each year for the foreseeable future, and it is also aging rapidly. Studies by Evercore ISI, a research firm, show that the elderly share of the population is rising more than twice as fast as it did in the United States and more than four times faster than in France at similar stages of development. Asked by an alarmed dinner companion about the threat robots posed to jobs in China, Nobel economist Daniel Kahneman responded: “You just don’t get it. In China, the robots are going to come just in time.” No wonder Beijing now offers heavy subsidies to companies involved in industrial automation.


And timing is critical. Those who fear the job-destroying impact of machines say this generation of technology is different because it is coming so fast. If older generations created tools for use by humans, such as sewing machines, the new forms of automation are imbued with artificial intelligence, capable of “machine learning” and of rapidly replacing humans in a broad swath of jobs, from manufacturing to services — even jobs that involve writing about robots. Concern about this disruptive advance has been stirred up by authorities such as Oxford University researchers Carl Benedikt Frey and Michael Osborne, who predicted in 2013 that nearly half of U.S. jobs would be at risk from automation in the next decade or two.


These alarms have sounded before, however. The Machine Intelligence Research Institute at the University of California at Berkeley has found that today, the average forecast for when artificial intelligence will arrive is about 20 years. But that was also the standard prediction in 1955. And often, humans find a way of working with their automated creations. After the introduction of supermarket scanners, the number of cashiers grew. Though legal-discovery software appeared to threaten the jobs of paralegals, their ranks increased, too. Now, many fear that self-driving trucks will displace millions of American truckers, but they may create more and better jobs for those who service those increasingly complex vehicles.


If automation was displacing human workers as fast as implied in recent books like Martin Ford’s “The Rise of the Robots,” then we should be seeing a negative impact on jobs already. We’re not. Since 2008, economic growth has been weak compared with that in other post-crisis recoveries, but job growth in the major industrial countries has been relatively strong. In the Group of Seven, the world’s top industrial countries, unemployment has fallen faster than expected in the face of weak economic growth, and faster than in any comparable period since at least the 1970s. The Japanese economy is growing at 0.8 percent, yet it is at full employment. According to my research, the job picture has been particularly strong in Germany, Japan and South Korea — the industrial countries that employ the most robots .


True, robots do represent a new obstacle for some poorer nations, namely those few that do not suffer from population decline. In the postwar era, countries like China escaped poverty by moving a rising young population off the farm and into more productive jobs in factories. Indeed, it was unusual for any country to sustain rapid growth unless the working-age population was increasing faster than 2 percent a year. My analysis shows that, in the 1980s, 17 of the 20 largest emerging economies had a working-age population expanding that fast, according to my research, but now there are only two: Nigeria and Saudi Arabia. And they will have a hard time moving a large segment of their young populations into industrial jobs, given that they now have to compete with robotic manufacturing elsewhere.


Yet for the rising number of countries facing population decline, the effort to lift the labor force has begun. Starting in the 1980s, led by Singapore, nations from Chile to Australia have offered baby bonuses for women to have more children, but many have found that these bonuses are ineffective in the face of stronger cultural forces, including the desire of many women to pursue a career before having children. Others have tried with some success to boost the workforce directly by raising the retirement age, offering women incentives to join or return to the labor force after having kids, and opening doors to immigrant workers.


The simple math, however, shows that particularly in rapidly aging, conservative societies such as Japan and Germany, none of these groups has the potential to make up for coming declines in the working-age population. Germany decided to admit roughly 1 million refugees in 2015, in part for economic reasons, but the resulting controversy has reduced the flow. Germany would have to admit 1.5 million each year through 2030 to fully offset the economic impact of its aging population. Japan, which on average admits fewer than 70,000 immigrants per year, would have to admit 1 million annually. Given the widespread political backlash against immigration, increases this large are unlikely.


So far, robots are drawing comparatively little populist fire, perhaps in part because their numbers are still quite low. Worldwide, the industrial labor force includes about 320 million humans, compared with just 1.6 million robots. That’s a huge gap, even counting the superior strength and speed of the robots. And most of them fall in the category of unintelligent machines, committed to a single task such as turning a bolt or painting a car door. Nearly half of them work in the auto industry, which is still the largest employer (of humans) in the United States.


In the future, economists may start counting robots the way they now count gains in the working-age population, as a driver of growth. For much of the world, robots will stand alongside immigrants, women and the elderly as a fourth pool of labor.


Whether by design or accident, many of the countries with the most rapidly aging populations already have the most robots. According to the International Federation of Robotics, the nations with the highest density of industrial robots include South Korea, with 531 per 10,000 employees, Japan with 305 and Germany with 301. The United States ranks eighth with 176. China is well behind with only 49, but on the bright side — arguably — it had the world’s fastest-growing robot population.


Today, population trends are the most powerful force shaping the rise and fall of nations, the starting point of any discussion about an economy’s prospects. Most of the world is graying fast, and the economic answer to aging will be all hands on deck, no matter what they’re made of. Researchers describe the ‘emotional chatting machine’ as a first attempt at the problem of creating machines that can fully understand user emotion


An “emotional chatting machine” has been developed by scientists, signalling the approach of an era in which human-robot interactions are seamless and go beyond the purely functional.


The chatbot, developed by a Chinese team, is seen as a significant step towards the goal of developing emotionally sophisticated robots.


The ECM, as it is known for short, was able to produce factually coherent answers whilst also imbuing its conversation with emotions such as happiness, sadness or disgust.


Prof Björn Schuller, a computer scientist at Imperial College London who was not involved in the latest advance, described the work as “an important step” towards personal assistants that could read the emotional undercurrent of a conversation and respond with something akin to empathy.


“This will be the next generation of intelligence to be met in daily experience, sooner rather than later,” he said.


The paper found that 61% of humans who tested the machine favoured the emotional versions to the neutral chatbot. Similar results have been found in so-called “Wizard of Oz” studies in which a human typing responses masquerades as advanced AI.


“It is not a question whether they are desirable – they clearly are – but in which applications they make sense and where they don’t,” said Schuller.


Minlie Huang, a computer scientist at Tsinghua University, Beijing and co-author, said: “We’re still far away from a machine that can fully understand the user’s emotion. This is just the first attempt at this problem.”






Huang and colleagues started by creating an “emotion classifying” algorithm that learned to detect emotion from 23,000 posts taken from the Chinese social media site Weibo. The posts had been manually classified by humans as sad, happy and so on.


The emotion classifier was then used to tag millions of social media interactions according to emotional content. This huge dataset served as a training ground for the chatbot to learn both how to answer questions and how to express emotion.


The resulting program could be switched into five possible modes – happy, sad, angry, disgusted, liking – depending on the user’s preference. In one example conversation a user typed in: “Worst day ever. I arrived late because of the traffic.”


In neutral mode, the chatbot droned: “You were late”. Alternative responses were: “Sometimes life just sucks!” (disgust mode), “I am always here to support you” (liking) or “Keep smiling! Things will get better” (happy – or, some might say, annoyingly chipper).


In the future, the team predict the software could also learn the appropriate emotion to express at a given time. “It could be mostly empathic,” said Huang, adding that a challenge would be to avoid the chatbot reinforcing negative feelings such as rage.


Until recently chatbots were widely regarded as a sideshow to more serious attempts at tackling machine intelligence. A chatbot known as Eugene Goostman managed to convince some judges they were talking to a human – but only by posing as a 13-year old Ukrainian boy with a limited grasp of English. Microsoft’s disastrous chatbot Tay was supposed to learn to chat from Twitter interactions, but was terminated after becoming a genocide-supporting Nazi less than 24 hours after being let loose on the internet.


The latest study shows that chatbots, driven by a machine learning approach, are starting to make significant headway. Sandra Wachter, a computer scientist at the Oxford Internet Institute, said that in future such algorithms are likely to be personalised. “Some of us prefer a tough-love pep talk, others prefer someone to rant with,” she said. “Humans often struggle with appropriate responses because of the complexity of emotions, so building technologies that could decipher accurately our ‘emotional code’ would be very impressive.”


As the stilted computer interactions of today are replaced by something approaching friendly chit-chat, new risks could be encountered.






One concern is the potential for technology designed to seduce the user into sharing sensitive personal data. “It could be that children share insights with their ‘artificial friends’ and this data might be stored,” said Wachter. “What if we were to find out that people are more likely to buy more products when they are angry, sad, or bored? The ability to detect these emotions and successfully manipulate them could be a very interesting tool for companies.”


There is also the potential for users to become emotionally dependent, or even romantically involved, with their computers.


“However, there is also a huge potential for good, such as existing software to teach children on the autism spectrum [about] emotional and social interaction,” said Schuller. “One has to carefully balance benefits and risks and ensure the best exploitation.”
"""

# %%
sentences = sent_tokenize(text)

# %%
for sent in sentences:
    readability_scores = Textatistic(sent).scores
    print("Flesch score for Sentence:"+ sent)
    print(readability_scores['flesch_score'])
# Out:
# Flesch score for Sentence:
# ﻿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business
#
#
# Ride-sharing firm Uber is facing a criminal investigation by the US government.
# 47.10548387096776
# Flesch score for Sentence:The scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.
# 63.020000000000024
# Flesch score for Sentence:The software, called "greyball", helped it identify officials seeking to stop the service running.
# 59.68214285714288
# Flesch score for Sentence:A spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.
# 67.53000000000003
# Flesch score for Sentence:It is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.
# 47.39434782608697
# Flesch score for Sentence:Bookings blocked
#
#
# In those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally.
# 38.37772727272727
# Flesch score for Sentence:Greyball worked out who the officials were and blocked them from booking rides with the company's drivers.
# 70.14470588235295
# Flesch score for Sentence:In a letter sent last week to transport regulators in Portland, Uber said it used the greyball software "exceedingly sparingly" in the city and had not used it since April 2015 when it was granted permission to operate.
# 50.270263157894775
# Flesch score for Sentence:Uber's use of the software was revealed by the New York Times earlier this year.
# 90.09000000000002
# Flesch score for Sentence:Uber defended its use in a blog saying the software helped it work out if a ride request was legitimate.
# 72.32500000000003
# Flesch score for Sentence:It helped Uber limit fraud and protect drivers from harm, it added.
# 95.955
# Flesch score for Sentence:It is not clear what sanctions Uber will face if the investigation finds that it did act illegally.
# 71.06500000000001
# Flesch score for Sentence:The criminal inquiry comes at a difficult time for Uber which has faced criticism on many fronts.
# 70.14470588235295
# Flesch score for Sentence:It is currently fighting a lawsuit from Google-backed self-driving car firm Waymo.Despite all the current hype about the rise of voice-assisted devices using Alexa and Siri, linguistics researcher Rachael Tatman found people complaining on social media that the technology still doesn’t understand them.
# 56.59000000000002
# Flesch score for Sentence:That’s especially true with regional accents of people who live in the South or are from countries like New Zealand, Tatman said last week during a conference in San Francisco.
# 60.76500000000003
# Flesch score for Sentence:“So this is the whatever the opposite of delight is as a user experience,” she said.
# 68.9825
# Flesch score for Sentence:“People are so upset that they’re going on Twitter and yelling about it.”
#
#
# Tatman, a doctoral candidate with the University of Washington’s linguistics department, was one of the speakers at a two-day Virtual Assistant Summit, which wrapped up Friday at the Park Central Hotel.
# 54.2775
# Flesch score for Sentence:The conference, and an adjacent Deep Learning Summit, drew about 600 people representing companies that are working on advancing artificial intelligence, machine learning and robotics.
# 12.26000000000002
# Flesch score for Sentence:Lots of people are already using those technologies in programs like Apple’s Siri.
# 63.486153846153854
# Flesch score for Sentence:They are moving beyond mobile phones and into smart-home devices like Amazon’s Echo.
# 77.81071428571428
# Flesch score for Sentence:Other fast-changing technologies include artificial intelligence and consumer robotics, especially with self-driving cars on the horizon.
# 24.064999999999998
# Flesch score for Sentence:But there’s still work to be done in each of those areas, speakers said.
# 95.93928571428573
# Flesch score for Sentence:For example, artificial speech recognition technologies still fall short of the way humans can quickly learn and discern speech patterns from each other in “as little as two sentences,” Tatman said.
# 49.83451612903227
# Flesch score for Sentence:But that’s because humans take into account other factors, such as the gender of person talking or whether they’ve previously met someone from the the same region, she said.
# 57.793103448275886
# Flesch score for Sentence:Tatman examined YouTube’s automatic captioning program, which can translate spoken words into text in several languages.
# 42.545000000000016
# Flesch score for Sentence:She found that more errors showed up in translations from speakers who had a Southern accent than from people who lived in California.
# 62.10739130434784
# Flesch score for Sentence:“The South is the largest demographic region in the United States,” she said.
# 89.51692307692309
# Flesch score for Sentence:“If you’re using a voice-based virtual assistant and you can’t deal with Southern speech, you’re going to have problems reaching this market.”
#
#
# For businesses trying to serve those markets, speech recognition technology could be crucial to future revenue, said Stephen Scarr, CEO of search services Info.com and eContext.
# 62.493401360544254
# Flesch score for Sentence:With 20 percent of all searches already done through voice, “this is really important, this is No.
# 80.09764705882354
# Flesch score for Sentence:1 on your radar,” Scarr told the developers.
# 82.39000000000001
# Flesch score for Sentence:As an example of the challenge, a recent YouTube video showed Amazon’s Alexa misunderstanding a young boy’s request to play a song, and instead offering to play an audio porn channel.
# 49.83451612903227
# Flesch score for Sentence:The conference touched on more than just speech technologies.
# 75.50000000000003
# Flesch score for Sentence:Alonso Martinez, a Pixar Animation Studios technical director, said robot developers could take cues from the ways animators create deep emotional connections with audiences.
# 23.850000000000023
# Flesch score for Sentence:“When you’re thinking about a robot, don’t think about it as a generic, faceless thing,” said Martinez, who developed characters in “Up” and “Inside Out,” two of the Emeryville company’s hit movies.
# 63.317500000000024
# Flesch score for Sentence:“You need to ask what makes them admirable.
# 103.54
# Flesch score for Sentence:What are the values that they have that I wish that I had in myself?”
#
#
# Elena Corina Grigore of Yale University’s Social Robotics Lab said robots now used in manufacturing can work by themselves because they are easily trained to perform specialized, repetitive tasks.
# 63.37318181818182
# Flesch score for Sentence:But robots are not well-equipped to collaborate with humans, she said.
# 74.805
# Flesch score for Sentence:That’s slowly changing with advances in artificial intelligence.
# 29.515000000000015
# Flesch score for Sentence:As an example, Grigore played a video of a robot trained to help a person with what can be a complex and maddening task — assembling a chair from Ikea.
# 63.62758620689657
# Flesch score for Sentence:Still, Grigore said, “We’re not getting replaced by robots anytime soon.
# 64.9245454545455
# Flesch score for Sentence:We’re not at a point where the robots have the intelligence or the physical capabilities necessary to perform all of these actions on their own.
# 46.10000000000002
# Flesch score for Sentence:Anything that is related to common sense or creativity or types of thinking that require on-the-spot flexibility in a dynamic and changing environment is still very hard to achieve for us.”
#
#
# Benny Evangelista is a San Francisco Chronicle staff writer.
# 60.634285714285724
# Flesch score for Sentence:Email: bevangelista@sfchronicle.com Twitter: @ChronicleBenny The French electorate heads to the polls in the second round of presidential elections on May 7, followed by votes in Britain and Germany in the coming months.
# 50.47625000000002
# Flesch score for Sentence:Computer scientists, tech giants and start-ups are using sophisticated algorithms and reams of online data to quickly — and automatically — spot fake news faster than traditional fact-checking groups can.
# 41.025000000000034
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# The goal, experts say, is to expand these digital tools across Europe, so the region can counter the fake news that caused so much confusion and anger during the United States presidential election in November, when outright false reports routinely spread like wildfire on Facebook and Twitter.
# 30.13056603773589
# Flesch score for Sentence:“Algorithms will have to do a lot of the heavy lifting when it comes to fighting misinformation,” said Claire Wardle, head of strategy and research at First Draft News, a nonprofit organization that has teamed up with tech companies and newsrooms to debunk fake reports about elections in the United States and Europe.
# 33.32301886792456
# Flesch score for Sentence:“It’s impossible to do all of this by hand.”
#
#
# Researchers have tried to learn from the United States’ run-in with fake news, but the problem in Europe has mutated, experts say, making it impossible to merely replicate American responses to the issue.
# 68.93343023255817
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# European countries have different languages, and their media markets are smaller than those in the United States.
# 54.750869565217414
# Flesch score for Sentence:That means groups that set up fake news sites in the United States, seeking to profit from online advertising when false claims were shared on social media, are less prevalent in Europe.
# 68.60500000000002
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# So far, outright fake news stories have been relatively rare.
# 58.4075
# Flesch score for Sentence:Instead, false reports have more often come from Europeans on social media taking real news out of context, as well as from fake claims spread by state-backed groups like Sputnik, the Russian news organization.
# 52.87000000000002
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# But with fake news already swirling around Europe’s forthcoming elections, analysts also worry that technology on its own may not be enough to combat the threat.
# 52.74250000000002
# Flesch score for Sentence:“There’s an increased amount of misinformation out there,” said Janis Sarts, director of the NATO Strategic Communications Center of Excellence, a think tank in Riga, Latvia, that will hold a hackathon with local coders in May to find potential tech solutions to this trend.
# 37.19772727272729
# Flesch score for Sentence:“State-based actors have been trying to amplify specific views to bring them into the mainstream.”
#
#
# Calls for combating fake news have focused on some of the biggest online players, including American giants like Facebook and Google.
# 62.30074324324326
# Flesch score for Sentence:Interested in all things tech?
# 83.32000000000004
# Flesch score for Sentence:The daily Bits newsletter will keep you updated on the latest from Silicon Valley and the technology industry, plus exclusive analysis from our reporters and editors.
# 37.27576923076927
# Flesch score for Sentence:Please verify you're not a robot by clicking the box.
# 86.70500000000001
# Flesch score for Sentence:Invalid email address.
# 62.79000000000002
# Flesch score for Sentence:Please re-enter.
# 90.99000000000004
# Flesch score for Sentence:You must select a newsletter to subscribe to.
# 71.81500000000001
# Flesch score for Sentence:Sign Up Receive occasional updates and special offers for The New York Times's products and services.
# 63.69500000000001
# Flesch score for Sentence:Thank you for subscribing.
# 75.87500000000001
# Flesch score for Sentence:An error has occurred.
# 75.87500000000001
# Flesch score for Sentence:Please try again later.
# 118.17500000000001
# Flesch score for Sentence:View all New York Times newsletters.
# 87.94500000000002
# Flesch score for Sentence:After criticism of its role in spreading false reports during the United States elections, Facebook introduced a fact-checking tool ahead of the Dutch elections in March and the first round of the French presidential election on April 23.
# 50.11153846153847
# Flesch score for Sentence:It also removed 30,000 accounts in France that had shared fake news, a small fraction of the approximately 33 million Facebook users in the country.
# 66.40400000000001
# Flesch score for Sentence:Photo
#
#
# Not everyone, though, has embraced Facebook’s response.
# 61.24000000000001
# Flesch score for Sentence:Most German publishers, for instance, have so far balked at participating in the company’s fact-checking efforts, saying it is the responsibility of the social network, not them, to debunk such claims.
# 39.523750000000035
# Flesch score for Sentence:German lawmakers are mulling potential hefty fines against tech companies if they do not clamp down on fake news and online hate speech.
# 69.46391304347827
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# Since last year, Google also has funded almost 20 European projects aimed at fact-checking potentially false reports.
# 59.10000000000004
# Flesch score for Sentence:That includes its support for two British groups looking to use artificial intelligence to automatically fact-check online claims ahead of the country’s June 8 parliamentary election.
# 32.163333333333355
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# It similarly has teamed up with French newsrooms to create digital tools, including ways to track trending topics during that country’s election.
# 39.429285714285754
# Flesch score for Sentence:David Dieudonné, head of the company’s news lab in France, said the project had debunked 43 reports since February (arguably a relatively small figure), including claims that Saudi Arabia was funding the campaign of Emmanuel Macron, the leading candidate.
# 43.60384615384616
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# “We’re trying something new,” Mr. Dieudonné said.
# 63.57596153846157
# Flesch score for Sentence:“There’s no easy answer for this complicated issue.”
#
#
# Not all potential solutions, though, are being driven by Silicon Valley’s big beasts.
# 63.23464285714289
# Flesch score for Sentence:David Chavalarias, a French academic, has created a digital tool that has analyzed more than 80 million Twitter messages about the French election, helping journalists and fact-checkers to quickly review claims that are spread on the social network.
# 43.60384615384616
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# After the presidential election in the United States last year, Dean Pomerleau, a computer scientist at Carnegie Mellon University in Pittsburgh, also challenged his followers on Twitter to come up with an algorithm that could distinguish fake claims from real news.
# 31.33
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# Working with Delip Rao, a former Google researcher, he offered a $2,000 prize to anyone who could meet his requirements.
# 56.798846153846185
# Flesch score for Sentence:By early this year, more than 100 teams from around the world had signed on to Mr. Pomerleau’s Fake News Challenge.
# 103.52035714285715
# Flesch score for Sentence:Using a database of verified articles and their artificial intelligence expertise, rival groups — a combination of college teams, independent programmers and groups from existing tech companies — already have been able to accurately predict the veracity of certain claims almost 90 percent of the time, Mr. Pomerleau said.
# 29.982500000000016
# Flesch score for Sentence:He hopes that figure will rise to the mid-90s before his challenge ends in June.
# 90.13250000000001
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# “This is just Round 1 of what we want to do,” said Mr. Pomerleau, who expects the teams to share their work with fact-checking groups worldwide.
# 82.41477272727275
# Flesch score for Sentence:“Next, we want to move toward multimedia content like videos.”
#
#
# Advertisement Continue reading the main story
#
#
# In the rush to find solutions to fake news, some within the industry are taking a decidedly more low-tech approach.
# 62.30074324324326
# Flesch score for Sentence:Jimmy Wales, the founder of Wikipedia, recently started a crowdfunding campaign to create a news organization that would combine professional journalists with digital volunteers, who would contribute to reports in a way similar to how articles are created on Wikipedia.
# 26.64500000000004
# Flesch score for Sentence:Part fact-checking site, part traditional newsroom, the project — called Wikitribune — was inspired by the effect of misinformation on the United States presidential election.
# 41.47500000000002
# Flesch score for Sentence:Mr. Wales said his project would choose subject areas based on the interests of the community of volunteers and paying subscribers to the service, relying more on traditional reporting techniques than high-tech wizardry.
# 57.70352941176472
# Flesch score for Sentence:Advertisement Continue reading the main story
#
#
# “The real impetus for this was fake news,” he said.
# 68.9825
# Flesch score for Sentence:“We want people to get behind topics, and then we’ll hire staff to cover them.” Ruchir Sharma, chief global strategist at Morgan Stanley Investment Management, is the author of “The Rise and Fall of Nations: Forces of Change in the The Post-Crisis World,” from which this essay is adapted.
# 71.48000000000002
# Flesch score for Sentence:A robot collects dishes to be cleaned at Chilli Padi Nonya Cafe in Singapore.
# 83.85357142857143
# Flesch score for Sentence:(REUTERS/Edgar Su)
#
#
# The United Nations forecasts that the global population will rise from 7.3 billion to nearly 10 billion by 2050, a big number that often prompts warnings about overpopulation.
# 52.305000000000035
# Flesch score for Sentence:Some have come from neo-Malthusians, who fear that population growth will outstrip the food supply, leaving a hungry planet.
# 68.09500000000004
# Flesch score for Sentence:Others appear in the tirades of anti-immigrant populists, invoking the specter of a rising tide of humanity as cause to slam borders shut.
# 62.62500000000003
# Flesch score for Sentence:Still others inspire a chorus of neo-Luddites, who fear that the “rise of the robots” is rapidly making human workers obsolete, a threat all the more alarming if the human population is exploding.
# 47.91323529411767
# Flesch score for Sentence:Before long, though, we’re more likely to treasure robots than to revile them.
# 76.50153846153849
# Flesch score for Sentence:They may be the one thing that can protect the global economy from the dangers that lie ahead.
# 89.865
# Flesch score for Sentence:An increase of 2.5 billion people may sound catastrophic.
# 66.10000000000002
# Flesch score for Sentence:But what matters for economic growth is not the number of people but the rate of population growth.
# 71.06500000000001
# Flesch score for Sentence:Since its peak in the 1960s, that rate has slumped by almost half to just 1 percent, and the U.N. forecast assumes that this slowdown will continue.
# 72.66500000000002
# Flesch score for Sentence:Women are having fewer children, so fewer people are entering the working ages between 15 and 64, and labor-force growth is poised to decline from Chile to China.
# 66.5448275862069
# Flesch score for Sentence:At the same time, owing to rapid advances in health care and medicine, people are living longer , and most of the coming global population increase will be among the retirement crowd.
# 60.750645161290336
# Flesch score for Sentence:These trends are toxic for economic growth, and boosting the number of robots may be the easiest answer for many countries.
# 64.66285714285716
# Flesch score for Sentence:One simple way to estimate how fast an economy can grow is by adding working-age population growth and productivity growth: If the number of workers and output per worker are both increasing by 1 percent a year, then economic output should rise by roughly 2 percent.
# 38.53
# Flesch score for Sentence:Over the past decade, both sides of that equation have declined dramatically across the world.
# 78.81000000000003
# Flesch score for Sentence:In the United States, productivity growth has fallen by almost half from its postwar average, but growth in the labor force has slid even faster, dropping by two-thirds to an average pace of 0.5 percent, according to calculations performed for my book.
# 43.1760465116279
# Flesch score for Sentence:Though many explanations have been offered for the slow recovery from the global financial crisis of 2008, the clearest answer may be aging populations.
# 45.00000000000003
# Flesch score for Sentence:Something will have to fill the void left by, say, retiring farmers, and particularly at a time of rising hostility to immigrants, it is likely to be farmbots.
# 54.5364285714286
# Flesch score for Sentence:It may not be long before economists are worrying about a global shortage of robots.
# 67.53000000000003
# Flesch score for Sentence:In many industrial countries, from Germany to Japan to South Korea, growth in the working-age population has already peaked, acting as a drag on the economy.
# 57.23000000000002
# Flesch score for Sentence:Widely overlooked, however, is the fact that the population-growth slowdown is unfolding even faster in the emerging world, according to my research.
# 54.750869565217414
# Flesch score for Sentence:Consider the turning point that China hit last year.
# 94.30000000000001
# Flesch score for Sentence:For the first time since records began in the 1950s, its working-age population growth was negative.
# 70.14470588235295
# Flesch score for Sentence:As a result, China’s labor force is expected to lose 1 million workers each year for the foreseeable future, and it is also aging rapidly.
# 66.40400000000001
# Flesch score for Sentence:Studies by Evercore ISI, a research firm, show that the elderly share of the population is rising more than twice as fast as it did in the United States and more than four times faster than in France at similar stages of development.
# 53.01325581395349
# Flesch score for Sentence:Asked by an alarmed dinner companion about the threat robots posed to jobs in China, Nobel economist Daniel Kahneman responded: “You just don’t get it.
# 63.020000000000024
# Flesch score for Sentence:In China, the robots are going to come just in time.” No wonder Beijing now offers heavy subsidies to companies involved in industrial automation.
# 57.18000000000001
# Flesch score for Sentence:And timing is critical.
# 54.72500000000002
# Flesch score for Sentence:Those who fear the job-destroying impact of machines say this generation of technology is different because it is coming so fast.
# 49.91409090909093
# Flesch score for Sentence:If older generations created tools for use by humans, such as sewing machines, the new forms of automation are imbued with artificial intelligence, capable of “machine learning” and of rapidly replacing humans in a broad swath of jobs, from manufacturing to services — even jobs that involve writing about robots.
# 18.977551020408185
# Flesch score for Sentence:Concern about this disruptive advance has been stirred up by authorities such as Oxford University researchers Carl Benedikt Frey and Michael Osborne, who predicted in 2013 that nearly half of U.S. jobs would be at risk from automation in the next decade or two.
# 48.36000000000004
# Flesch score for Sentence:These alarms have sounded before, however.
# 73.84500000000001
# Flesch score for Sentence:The Machine Intelligence Research Institute at the University of California at Berkeley has found that today, the average forecast for when artificial intelligence will arrive is about 20 years.
# 25.703448275862087
# Flesch score for Sentence:But that was also the standard prediction in 1955.
# 84.90000000000003
# Flesch score for Sentence:And often, humans find a way of working with their automated creations.
# 67.75500000000001
# Flesch score for Sentence:After the introduction of supermarket scanners, the number of cashiers grew.
# 49.54272727272729
# Flesch score for Sentence:Though legal-discovery software appeared to threaten the jobs of paralegals, their ranks increased, too.
# 61.890000000000015
# Flesch score for Sentence:Now, many fear that self-driving trucks will displace millions of American truckers, but they may create more and better jobs for those who service those increasingly complex vehicles.
# 51.95862068965518
# Flesch score for Sentence:If automation was displacing human workers as fast as implied in recent books like Martin Ford’s “The Rise of the Robots,” then we should be seeing a negative impact on jobs already.
# 52.74250000000002
# Flesch score for Sentence:We’re not.
# 77.90500000000002
# Flesch score for Sentence:Since 2008, economic growth has been weak compared with that in other post-crisis recoveries, but job growth in the major industrial countries has been relatively strong.
# 57.23000000000002
# Flesch score for Sentence:In the Group of Seven, the world’s top industrial countries, unemployment has fallen faster than expected in the face of weak economic growth, and faster than in any comparable period since at least the 1970s.
# 57.70428571428573
# Flesch score for Sentence:The Japanese economy is growing at 0.8 percent, yet it is at full employment.
# 71.76785714285715
# Flesch score for Sentence:According to my research, the job picture has been particularly strong in Germany, Japan and South Korea — the industrial countries that employ the most robots .
# 49.48400000000001
# Flesch score for Sentence:True, robots do represent a new obstacle for some poorer nations, namely those few that do not suffer from population decline.
# 56.6057142857143
# Flesch score for Sentence:In the postwar era, countries like China escaped poverty by moving a rising young population off the farm and into more productive jobs in factories.
# 56.252000000000024
# Flesch score for Sentence:Indeed, it was unusual for any country to sustain rapid growth unless the working-age population was increasing faster than 2 percent a year.
# 55.57500000000003
# Flesch score for Sentence:My analysis shows that, in the 1980s, 17 of the 20 largest emerging economies had a working-age population expanding that fast, according to my research, but now there are only two: Nigeria and Saudi Arabia.
# 52.79500000000003
# Flesch score for Sentence:And they will have a hard time moving a large segment of their young populations into industrial jobs, given that they now have to compete with robotic manufacturing elsewhere.
# 51.95862068965518
# Flesch score for Sentence:Yet for the rising number of countries facing population decline, the effort to lift the labor force has begun.
# 53.97105263157897
# Flesch score for Sentence:Starting in the 1980s, led by Singapore, nations from Chile to Australia have offered baby bonuses for women to have more children, but many have found that these bonuses are ineffective in the face of stronger cultural forces, including the desire of many women to pursue a career before having children.
# 38.9523529411765
# Flesch score for Sentence:Others have tried with some success to boost the workforce directly by raising the retirement age, offering women incentives to join or return to the labor force after having kids, and opening doors to immigrant workers.
# 43.395000000000024
# Flesch score for Sentence:The simple math, however, shows that particularly in rapidly aging, conservative societies such as Japan and Germany, none of these groups has the potential to make up for coming declines in the working-age population.
# 35.95000000000002
# Flesch score for Sentence:Germany decided to admit roughly 1 million refugees in 2015, in part for economic reasons, but the resulting controversy has reduced the flow.
# 58.429130434782635
# Flesch score for Sentence:Germany would have to admit 1.5 million each year through 2030 to fully offset the economic impact of its aging population.
# 60.634285714285724
# Flesch score for Sentence:Japan, which on average admits fewer than 70,000 immigrants per year, would have to admit 1 million annually.
# 56.965
# Flesch score for Sentence:Given the widespread political backlash against immigration, increases this large are unlikely.
# 39.55500000000001
# Flesch score for Sentence:So far, robots are drawing comparatively little populist fire, perhaps in part because their numbers are still quite low.
# 58.42368421052632
# Flesch score for Sentence:Worldwide, the industrial labor force includes about 320 million humans, compared with just 1.6 million robots.
# 53.120000000000005
# Flesch score for Sentence:That’s a huge gap, even counting the superior strength and speed of the robots.
# 83.85357142857143
# Flesch score for Sentence:And most of them fall in the category of unintelligent machines, committed to a single task such as turning a bolt or painting a car door.
# 56.798846153846185
# Flesch score for Sentence:Nearly half of them work in the auto industry, which is still the largest employer (of humans) in the United States.
# 84.8057142857143
# Flesch score for Sentence:In the future, economists may start counting robots the way they now count gains in the working-age population, as a driver of growth.
# 66.15000000000003
# Flesch score for Sentence:For much of the world, robots will stand alongside immigrants, women and the elderly as a fourth pool of labor.
# 76.55500000000004
# Flesch score for Sentence:Whether by design or accident, many of the countries with the most rapidly aging populations already have the most robots.
# 59.63500000000003
# Flesch score for Sentence:According to the International Federation of Robotics, the nations with the highest density of industrial robots include South Korea, with 531 per 10,000 employees, Japan with 305 and Germany with 301.
# 38.91838709677421
# Flesch score for Sentence:The United States ranks eighth with 176.
# 115.13000000000002
# Flesch score for Sentence:China is well behind with only 49, but on the bright side — arguably — it had the world’s fastest-growing robot population.
# 72.72000000000003
# Flesch score for Sentence:Today, population trends are the most powerful force shaping the rise and fall of nations, the starting point of any discussion about an economy’s prospects.
# 56.252000000000024
# Flesch score for Sentence:Most of the world is graying fast, and the economic answer to aging will be all hands on deck, no matter what they’re made of.
# 76.55600000000001
# Flesch score for Sentence:Researchers describe the ‘emotional chatting machine’ as a first attempt at the problem of creating machines that can fully understand user emotion
#
#
# An “emotional chatting machine” has been developed by scientists, signalling the approach of an era in which human-robot interactions are seamless and go beyond the purely functional.
# 17.341000000000037
# Flesch score for Sentence:The chatbot, developed by a Chinese team, is seen as a significant step towards the goal of developing emotionally sophisticated robots.
# 32.43428571428572
# Flesch score for Sentence:The ECM, as it is known for short, was able to produce factually coherent answers whilst also imbuing its conversation with emotions such as happiness, sadness or disgust.
# 45.4721428571429
# Flesch score for Sentence:Prof Björn Schuller, a computer scientist at Imperial College London who was not involved in the latest advance, described the work as “an important step” towards personal assistants that could read the emotional undercurrent of a conversation and respond with something akin to empathy.
# 23.738636363636374
# Flesch score for Sentence:“This will be the next generation of intelligence to be met in daily experience, sooner rather than later,” he said.
# 59.63500000000003
# Flesch score for Sentence:The paper found that 61% of humans who tested the machine favoured the emotional versions to the neutral chatbot.
# 71.78157894736843
# Flesch score for Sentence:Similar results have been found in so-called “Wizard of Oz” studies in which a human typing responses masquerades as advanced AI.
# 61.45045454545455
# Flesch score for Sentence:“It is not a question whether they are desirable – they clearly are – but in which applications they make sense and where they don’t,” said Schuller.
# 73.17200000000001
# Flesch score for Sentence:Minlie Huang, a computer scientist at Tsinghua University, Beijing and co-author, said: “We’re still far away from a machine that can fully understand the user’s emotion.
# 53.54500000000003
# Flesch score for Sentence:This is just the first attempt at this problem.”
#
#
#
#
#
#
# Huang and colleagues started by creating an “emotion classifying” algorithm that learned to detect emotion from 23,000 posts taken from the Chinese social media site Weibo.
# 63.381071428571445
# Flesch score for Sentence:The posts had been manually classified by humans as sad, happy and so on.
# 77.81071428571428
# Flesch score for Sentence:The emotion classifier was then used to tag millions of social media interactions according to emotional content.
# 40.2858823529412
# Flesch score for Sentence:This huge dataset served as a training ground for the chatbot to learn both how to answer questions and how to express emotion.
# 76.82043478260871
# Flesch score for Sentence:The resulting program could be switched into five possible modes – happy, sad, angry, disgusted, liking – depending on the user’s preference.
# 51.17500000000004
# Flesch score for Sentence:In one example conversation a user typed in: “Worst day ever.
# 72.61545454545457
# Flesch score for Sentence:I arrived late because of the traffic.”
#
#
# In neutral mode, the chatbot droned: “You were late”.
# 87.67750000000001
# Flesch score for Sentence:Alternative responses were: “Sometimes life just sucks!” (disgust mode), “I am always here to support you” (liking) or “Keep smiling!
# 69.78500000000001
# Flesch score for Sentence:Things will get better” (happy – or, some might say, annoyingly chipper).
# 80.30636363636367
# Flesch score for Sentence:In the future, the team predict the software could also learn the appropriate emotion to express at a given time.
# 68.09500000000004
# Flesch score for Sentence:“It could be mostly empathic,” said Huang, adding that a challenge would be to avoid the chatbot reinforcing negative feelings such as rage.
# 65.78565217391306
# Flesch score for Sentence:Until recently chatbots were widely regarded as a sideshow to more serious attempts at tackling machine intelligence.
# 45.26235294117649
# Flesch score for Sentence:A chatbot known as Eugene Goostman managed to convince some judges they were talking to a human – but only by posing as a 13-year old Ukrainian boy with a limited grasp of English.
# 65.3308823529412
# Flesch score for Sentence:Microsoft’s disastrous chatbot Tay was supposed to learn to chat from Twitter interactions, but was terminated after becoming a genocide-supporting Nazi less than 24 hours after being let loose on the internet.
# 34.903636363636366
# Flesch score for Sentence:The latest study shows that chatbots, driven by a machine learning approach, are starting to make significant headway.
# 56.965
# Flesch score for Sentence:Sandra Wachter, a computer scientist at the Oxford Internet Institute, said that in future such algorithms are likely to be personalised.
# 44.52000000000001
# Flesch score for Sentence:“Some of us prefer a tough-love pep talk, others prefer someone to rant with,” she said.
# 85.07411764705884
# Flesch score for Sentence:“Humans often struggle with appropriate responses because of the complexity of emotions, so building technologies that could decipher accurately our ‘emotional code’ would be very impressive.”
#
#
# As the stilted computer interactions of today are replaced by something approaching friendly chit-chat, new risks could be encountered.
# 38.19869565217394
# Flesch score for Sentence:One concern is the potential for technology designed to seduce the user into sharing sensitive personal data.
# 50.2388235294118
# Flesch score for Sentence:“It could be that children share insights with their ‘artificial friends’ and this data might be stored,” said Wachter.
# 80.68684210526318
# Flesch score for Sentence:“What if we were to find out that people are more likely to buy more products when they are angry, sad, or bored?
# 87.85521739130436
# Flesch score for Sentence:The ability to detect these emotions and successfully manipulate them could be a very interesting tool for companies.”
#
#
# There is also the potential for users to become emotionally dependent, or even romantically involved, with their computers.
# 42.86500000000001
# Flesch score for Sentence:“However, there is also a huge potential for good, such as existing software to teach children on the autism spectrum [about] emotional and social interaction,” said Schuller.
# 54.09666666666669
# Flesch score for Sentence:“One has to carefully balance benefits and risks and ensure the best exploitation.”
# 63.486153846153854

# %%
for sent in sentences:
    readability_scores = Textatistic(sent).scores
    print("GunningFog score for Sentence:"+ sent)
    print(readability_scores['gunningfog_score'])
# Out:
# GunningFog score for Sentence:
# ﻿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business
#
#
# Ride-sharing firm Uber is facing a criminal investigation by the US government.
# 17.561290322580646
# GunningFog score for Sentence:The scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.
# 11.600000000000001
# GunningFog score for Sentence:The software, called "greyball", helped it identify officials seeking to stop the service running.
# 8.457142857142857
# GunningFog score for Sentence:A spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.
# 8.666666666666668
# GunningFog score for Sentence:It is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.
# 14.417391304347825
# GunningFog score for Sentence:Bookings blocked
#
#
# In those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally.
# 17.89090909090909
# GunningFog score for Sentence:Greyball worked out who the officials were and blocked them from booking rides with the company's drivers.
# 11.505882352941178
# GunningFog score for Sentence:In a letter sent last week to transport regulators in Portland, Uber said it used the greyball software "exceedingly sparingly" in the city and had not used it since April 2015 when it was granted permission to operate.
# 19.410526315789475
# GunningFog score for Sentence:Uber's use of the software was revealed by the New York Times earlier this year.
# 6.0
# GunningFog score for Sentence:Uber defended its use in a blog saying the software helped it work out if a ride request was legitimate.
# 10.0
# GunningFog score for Sentence:It helped Uber limit fraud and protect drivers from harm, it added.
# 4.800000000000001
# GunningFog score for Sentence:It is not clear what sanctions Uber will face if the investigation finds that it did act illegally.
# 11.644444444444446
# GunningFog score for Sentence:The criminal inquiry comes at a difficult time for Uber which has faced criticism on many fronts.
# 13.858823529411765
# GunningFog score for Sentence:It is currently fighting a lawsuit from Google-backed self-driving car firm Waymo.Despite all the current hype about the rise of voice-assisted devices using Alexa and Siri, linguistics researcher Rachael Tatman found people complaining on social media that the technology still doesn’t understand them.
# 13.547826086956523
# GunningFog score for Sentence:That’s especially true with regional accents of people who live in the South or are from countries like New Zealand, Tatman said last week during a conference in San Francisco.
# 14.666666666666666
# GunningFog score for Sentence:“So this is the whatever the opposite of delight is as a user experience,” she said.
# 11.4
# GunningFog score for Sentence:“People are so upset that they’re going on Twitter and yelling about it.”
#
#
# Tatman, a doctoral candidate with the University of Washington’s linguistics department, was one of the speakers at a two-day Virtual Assistant Summit, which wrapped up Friday at the Park Central Hotel.
# 13.444444444444446
# GunningFog score for Sentence:The conference, and an adjacent Deep Learning Summit, drew about 600 people representing companies that are working on advancing artificial intelligence, machine learning and robotics.
# 22.8
# GunningFog score for Sentence:Lots of people are already using those technologies in programs like Apple’s Siri.
# 8.276923076923078
# GunningFog score for Sentence:They are moving beyond mobile phones and into smart-home devices like Amazon’s Echo.
# 5.6000000000000005
# GunningFog score for Sentence:Other fast-changing technologies include artificial intelligence and consumer robotics, especially with self-driving cars on the horizon.
# 18.311111111111114
# GunningFog score for Sentence:But there’s still work to be done in each of those areas, speakers said.
# 5.6000000000000005
# GunningFog score for Sentence:For example, artificial speech recognition technologies still fall short of the way humans can quickly learn and discern speech patterns from each other in “as little as two sentences,” Tatman said.
# 17.561290322580646
# GunningFog score for Sentence:But that’s because humans take into account other factors, such as the gender of person talking or whether they’ve previously met someone from the the same region, she said.
# 12.979310344827589
# GunningFog score for Sentence:Tatman examined YouTube’s automatic captioning program, which can translate spoken words into text in several languages.
# 13.9
# GunningFog score for Sentence:She found that more errors showed up in translations from speakers who had a Southern accent than from people who lived in California.
# 12.678260869565218
# GunningFog score for Sentence:“The South is the largest demographic region in the United States,” she said.
# 8.276923076923078
# GunningFog score for Sentence:“If you’re using a voice-based virtual assistant and you can’t deal with Southern speech, you’re going to have problems reaching this market.”
#
#
# For businesses trying to serve those markets, speech recognition technology could be crucial to future revenue, said Stephen Scarr, CEO of search services Info.com and eContext.
# 9.798639455782315
# GunningFog score for Sentence:With 20 percent of all searches already done through voice, “this is really important, this is No.
# 9.15294117647059
# GunningFog score for Sentence:1 on your radar,” Scarr told the developers.
# 8.200000000000001
# GunningFog score for Sentence:As an example of the challenge, a recent YouTube video showed Amazon’s Alexa misunderstanding a young boy’s request to play a song, and instead offering to play an audio porn channel.
# 16.270967741935486
# GunningFog score for Sentence:The conference touched on more than just speech technologies.
# 12.488888888888889
# GunningFog score for Sentence:Alonso Martinez, a Pixar Animation Studios technical director, said robot developers could take cues from the ways animators create deep emotional connections with audiences.
# 21.26666666666667
# GunningFog score for Sentence:“When you’re thinking about a robot, don’t think about it as a generic, faceless thing,” said Martinez, who developed characters in “Up” and “Inside Out,” two of the Emeryville company’s hit movies.
# 15.3
# GunningFog score for Sentence:“You need to ask what makes them admirable.
# 3.2
# GunningFog score for Sentence:What are the values that they have that I wish that I had in myself?”
#
#
# Elena Corina Grigore of Yale University’s Social Robotics Lab said robots now used in manufacturing can work by themselves because they are easily trained to perform specialized, repetitive tasks.
# 11.527272727272727
# GunningFog score for Sentence:But robots are not well-equipped to collaborate with humans, she said.
# 8.133333333333333
# GunningFog score for Sentence:That’s slowly changing with advances in artificial intelligence.
# 13.200000000000001
# GunningFog score for Sentence:As an example, Grigore played a video of a robot trained to help a person with what can be a complex and maddening task — assembling a chair from Ikea.
# 15.73793103448276
# GunningFog score for Sentence:Still, Grigore said, “We’re not getting replaced by robots anytime soon.
# 4.4
# GunningFog score for Sentence:We’re not at a point where the robots have the intelligence or the physical capabilities necessary to perform all of these actions on their own.
# 16.400000000000002
# GunningFog score for Sentence:Anything that is related to common sense or creativity or types of thinking that require on-the-spot flexibility in a dynamic and changing environment is still very hard to achieve for us.”
#
#
# Benny Evangelista is a San Francisco Chronicle staff writer.
# 13.161904761904763
# GunningFog score for Sentence:Email: bevangelista@sfchronicle.com Twitter: @ChronicleBenny The French electorate heads to the polls in the second round of presidential elections on May 7, followed by votes in Britain and Germany in the coming months.
# 10.15
# GunningFog score for Sentence:Computer scientists, tech giants and start-ups are using sophisticated algorithms and reams of online data to quickly — and automatically — spot fake news faster than traditional fact-checking groups can.
# 18.666666666666668
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# The goal, experts say, is to expand these digital tools across Europe, so the region can counter the fake news that caused so much confusion and anger during the United States presidential election in November, when outright false reports routinely spread like wildfire on Facebook and Twitter.
# 24.218867924528304
# GunningFog score for Sentence:“Algorithms will have to do a lot of the heavy lifting when it comes to fighting misinformation,” said Claire Wardle, head of strategy and research at First Draft News, a nonprofit organization that has teamed up with tech companies and newsrooms to debunk fake reports about elections in the United States and Europe.
# 24.218867924528304
# GunningFog score for Sentence:“It’s impossible to do all of this by hand.”
#
#
# Researchers have tried to learn from the United States’ run-in with fake news, but the problem in Europe has mutated, experts say, making it impossible to merely replicate American responses to the issue.
# 11.390697674418604
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# European countries have different languages, and their media markets are smaller than those in the United States.
# 12.678260869565218
# GunningFog score for Sentence:That means groups that set up fake news sites in the United States, seeking to profit from online advertising when false claims were shared on social media, are less prevalent in Europe.
# 14.05
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# So far, outright fake news stories have been relatively rare.
# 11.4
# GunningFog score for Sentence:Instead, false reports have more often come from Europeans on social media taking real news out of context, as well as from fake claims spread by state-backed groups like Sputnik, the Russian news organization.
# 15.142857142857142
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# But with fake news already swirling around Europe’s forthcoming elections, analysts also worry that technology on its own may not be enough to combat the threat.
# 17.8
# GunningFog score for Sentence:“There’s an increased amount of misinformation out there,” said Janis Sarts, director of the NATO Strategic Communications Center of Excellence, a think tank in Riga, Latvia, that will hold a hackathon with local coders in May to find potential tech solutions to this trend.
# 23.054545454545455
# GunningFog score for Sentence:“State-based actors have been trying to amplify specific views to bring them into the mainstream.”
#
#
# Calls for combating fake news have focused on some of the biggest online players, including American giants like Facebook and Google.
# 10.643243243243244
# GunningFog score for Sentence:Interested in all things tech?
# 10.0
# GunningFog score for Sentence:The daily Bits newsletter will keep you updated on the latest from Silicon Valley and the technology industry, plus exclusive analysis from our reporters and editors.
# 21.16923076923077
# GunningFog score for Sentence:Please verify you're not a robot by clicking the box.
# 4.0
# GunningFog score for Sentence:Invalid email address.
# 1.2000000000000002
# GunningFog score for Sentence:Please re-enter.
# 1.2000000000000002
# GunningFog score for Sentence:You must select a newsletter to subscribe to.
# 8.200000000000001
# GunningFog score for Sentence:Sign Up Receive occasional updates and special offers for The New York Times's products and services.
# 8.9
# GunningFog score for Sentence:Thank you for subscribing.
# 11.600000000000001
# GunningFog score for Sentence:An error has occurred.
# 1.6
# GunningFog score for Sentence:Please try again later.
# 1.6
# GunningFog score for Sentence:View all New York Times newsletters.
# 9.066666666666666
# GunningFog score for Sentence:After criticism of its role in spreading false reports during the United States elections, Facebook introduced a fact-checking tool ahead of the Dutch elections in March and the first round of the French presidential election on April 23.
# 18.676923076923078
# GunningFog score for Sentence:It also removed 30,000 accounts in France that had shared fake news, a small fraction of the approximately 33 million Facebook users in the country.
# 11.600000000000001
# GunningFog score for Sentence:Photo
#
#
# Not everyone, though, has embraced Facebook’s response.
# 8.200000000000001
# GunningFog score for Sentence:Most German publishers, for instance, have so far balked at participating in the company’s fact-checking efforts, saying it is the responsibility of the social network, not them, to debunk such claims.
# 16.55
# GunningFog score for Sentence:German lawmakers are mulling potential hefty fines against tech companies if they do not clamp down on fake news and online hate speech.
# 14.417391304347825
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# Since last year, Google also has funded almost 20 European projects aimed at fact-checking potentially false reports.
# 12.933333333333332
# GunningFog score for Sentence:That includes its support for two British groups looking to use artificial intelligence to automatically fact-check online claims ahead of the country’s June 8 parliamentary election.
# 16.725925925925925
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# It similarly has teamed up with French newsrooms to create digital tools, including ways to track trending topics during that country’s election.
# 16.914285714285715
# GunningFog score for Sentence:David Dieudonné, head of the company’s news lab in France, said the project had debunked 43 reports since February (arguably a relatively small figure), including claims that Saudi Arabia was funding the campaign of Emmanuel Macron, the leading candidate.
# 19.702564102564104
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# “We’re trying something new,” Mr. Dieudonné said.
# 5.676923076923078
# GunningFog score for Sentence:“There’s no easy answer for this complicated issue.”
#
#
# Not all potential solutions, though, are being driven by Silicon Valley’s big beasts.
# 11.81904761904762
# GunningFog score for Sentence:David Chavalarias, a French academic, has created a digital tool that has analyzed more than 80 million Twitter messages about the French election, helping journalists and fact-checkers to quickly review claims that are spread on the social network.
# 18.676923076923078
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# After the presidential election in the United States last year, Dean Pomerleau, a computer scientist at Carnegie Mellon University in Pittsburgh, also challenged his followers on Twitter to come up with an algorithm that could distinguish fake claims from real news.
# 23.906382978723407
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# Working with Delip Rao, a former Google researcher, he offered a $2,000 prize to anyone who could meet his requirements.
# 13.476923076923079
# GunningFog score for Sentence:By early this year, more than 100 teams from around the world had signed on to Mr. Pomerleau’s Fake News Challenge.
# 4.2
# GunningFog score for Sentence:Using a database of verified articles and their artificial intelligence expertise, rival groups — a combination of college teams, independent programmers and groups from existing tech companies — already have been able to accurately predict the veracity of certain claims almost 90 percent of the time, Mr. Pomerleau said.
# 19.61276595744681
# GunningFog score for Sentence:He hopes that figure will rise to the mid-90s before his challenge ends in June.
# 6.4
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# “This is just Round 1 of what we want to do,” said Mr. Pomerleau, who expects the teams to share their work with fact-checking groups worldwide.
# 7.8121212121212125
# GunningFog score for Sentence:“Next, we want to move toward multimedia content like videos.”
#
#
# Advertisement Continue reading the main story
#
#
# In the rush to find solutions to fake news, some within the industry are taking a decidedly more low-tech approach.
# 12.805405405405407
# GunningFog score for Sentence:Jimmy Wales, the founder of Wikipedia, recently started a crowdfunding campaign to create a news organization that would combine professional journalists with digital volunteers, who would contribute to reports in a way similar to how articles are created on Wikipedia.
# 25.0
# GunningFog score for Sentence:Part fact-checking site, part traditional newsroom, the project — called Wikitribune — was inspired by the effect of misinformation on the United States presidential election.
# 16.266666666666666
# GunningFog score for Sentence:Mr. Wales said his project would choose subject areas based on the interests of the community of volunteers and paying subscribers to the service, relying more on traditional reporting techniques than high-tech wizardry.
# 13.858823529411765
# GunningFog score for Sentence:Advertisement Continue reading the main story
#
#
# “The real impetus for this was fake news,” he said.
# 11.4
# GunningFog score for Sentence:“We want people to get behind topics, and then we’ll hire staff to cover them.” Ruchir Sharma, chief global strategist at Morgan Stanley Investment Management, is the author of “The Rise and Fall of Nations: Forces of Change in the The Post-Crisis World,” from which this essay is adapted.
# 11.600000000000001
# GunningFog score for Sentence:A robot collects dishes to be cleaned at Chilli Padi Nonya Cafe in Singapore.
# 8.457142857142857
# GunningFog score for Sentence:(REUTERS/Edgar Su)
#
#
# The United Nations forecasts that the global population will rise from 7.3 billion to nearly 10 billion by 2050, a big number that often prompts warnings about overpopulation.
# 14.666666666666666
# GunningFog score for Sentence:Some have come from neo-Malthusians, who fear that population growth will outstrip the food supply, leaving a hungry planet.
# 10.0
# GunningFog score for Sentence:Others appear in the tirades of anti-immigrant populists, invoking the specter of a rising tide of humanity as cause to slam borders shut.
# 14.600000000000001
# GunningFog score for Sentence:Still others inspire a chorus of neo-Luddites, who fear that the “rise of the robots” is rapidly making human workers obsolete, a threat all the more alarming if the human population is exploding.
# 17.129411764705885
# GunningFog score for Sentence:Before long, though, we’re more likely to treasure robots than to revile them.
# 5.2
# GunningFog score for Sentence:They may be the one thing that can protect the global economy from the dangers that lie ahead.
# 7.2
# GunningFog score for Sentence:An increase of 2.5 billion people may sound catastrophic.
# 8.044444444444444
# GunningFog score for Sentence:But what matters for economic growth is not the number of people but the rate of population growth.
# 9.422222222222222
# GunningFog score for Sentence:Since its peak in the 1960s, that rate has slumped by almost half to just 1 percent, and the U.N. forecast assumes that this slowdown will continue.
# 11.200000000000001
# GunningFog score for Sentence:Women are having fewer children, so fewer people are entering the working ages between 15 and 64, and labor-force growth is poised to decline from Chile to China.
# 12.979310344827589
# GunningFog score for Sentence:At the same time, owing to rapid advances in health care and medicine, people are living longer , and most of the coming global population increase will be among the retirement crowd.
# 14.980645161290324
# GunningFog score for Sentence:These trends are toxic for economic growth, and boosting the number of robots may be the easiest answer for many countries.
# 10.304761904761905
# GunningFog score for Sentence:One simple way to estimate how fast an economy can grow is by adding working-age population growth and productivity growth: If the number of workers and output per worker are both increasing by 1 percent a year, then economic output should rise by roughly 2 percent.
# 22.20425531914894
# GunningFog score for Sentence:Over the past decade, both sides of that equation have declined dramatically across the world.
# 8.666666666666668
# GunningFog score for Sentence:In the United States, productivity growth has fallen by almost half from its postwar average, but growth in the labor force has slid even faster, dropping by two-thirds to an average pace of 0.5 percent, according to calculations performed for my book.
# 21.851162790697675
# GunningFog score for Sentence:Though many explanations have been offered for the slow recovery from the global financial crisis of 2008, the clearest answer may be aging populations.
# 16.266666666666666
# GunningFog score for Sentence:Something will have to fill the void left by, say, retiring farmers, and particularly at a time of rising hostility to immigrants, it is likely to be farmbots.
# 16.914285714285715
# GunningFog score for Sentence:It may not be long before economists are worrying about a global shortage of robots.
# 11.333333333333336
# GunningFog score for Sentence:In many industrial countries, from Germany to Japan to South Korea, growth in the working-age population has already peaked, acting as a drag on the economy.
# 13.762962962962963
# GunningFog score for Sentence:Widely overlooked, however, is the fact that the population-growth slowdown is unfolding even faster in the emerging world, according to my research.
# 14.417391304347825
# GunningFog score for Sentence:Consider the turning point that China hit last year.
# 3.6
# GunningFog score for Sentence:For the first time since records began in the 1950s, its working-age population growth was negative.
# 11.505882352941178
# GunningFog score for Sentence:As a result, China’s labor force is expected to lose 1 million workers each year for the foreseeable future, and it is also aging rapidly.
# 11.600000000000001
# GunningFog score for Sentence:Studies by Evercore ISI, a research firm, show that the elderly share of the population is rising more than twice as fast as it did in the United States and more than four times faster than in France at similar stages of development.
# 19.990697674418605
# GunningFog score for Sentence:Asked by an alarmed dinner companion about the threat robots posed to jobs in China, Nobel economist Daniel Kahneman responded: “You just don’t get it.
# 14.8
# GunningFog score for Sentence:In China, the robots are going to come just in time.” No wonder Beijing now offers heavy subsidies to companies involved in industrial automation.
# 11.466666666666667
# GunningFog score for Sentence:And timing is critical.
# 11.600000000000001
# GunningFog score for Sentence:Those who fear the job-destroying impact of machines say this generation of technology is different because it is coming so fast.
# 16.072727272727274
# GunningFog score for Sentence:If older generations created tools for use by humans, such as sewing machines, the new forms of automation are imbued with artificial intelligence, capable of “machine learning” and of rapidly replacing humans in a broad swath of jobs, from manufacturing to services — even jobs that involve writing about robots.
# 25.314285714285717
# GunningFog score for Sentence:Concern about this disruptive advance has been stirred up by authorities such as Oxford University researchers Carl Benedikt Frey and Michael Osborne, who predicted in 2013 that nearly half of U.S. jobs would be at risk from automation in the next decade or two.
# 20.666666666666668
# GunningFog score for Sentence:These alarms have sounded before, however.
# 2.4000000000000004
# GunningFog score for Sentence:The Machine Intelligence Research Institute at the University of California at Berkeley has found that today, the average forecast for when artificial intelligence will arrive is about 20 years.
# 19.875862068965517
# GunningFog score for Sentence:But that was also the standard prediction in 1955.
# 8.044444444444444
# GunningFog score for Sentence:And often, humans find a way of working with their automated creations.
# 8.133333333333333
# GunningFog score for Sentence:After the introduction of supermarket scanners, the number of cashiers grew.
# 11.672727272727274
# GunningFog score for Sentence:Though legal-discovery software appeared to threaten the jobs of paralegals, their ranks increased, too.
# 11.333333333333336
# GunningFog score for Sentence:Now, many fear that self-driving trucks will displace millions of American truckers, but they may create more and better jobs for those who service those increasingly complex vehicles.
# 15.73793103448276
# GunningFog score for Sentence:If automation was displacing human workers as fast as implied in recent books like Martin Ford’s “The Rise of the Robots,” then we should be seeing a negative impact on jobs already.
# 16.55
# GunningFog score for Sentence:We’re not.
# 0.8
# GunningFog score for Sentence:Since 2008, economic growth has been weak compared with that in other post-crisis recoveries, but job growth in the major industrial countries has been relatively strong.
# 15.244444444444447
# GunningFog score for Sentence:In the Group of Seven, the world’s top industrial countries, unemployment has fallen faster than expected in the face of weak economic growth, and faster than in any comparable period since at least the 1970s.
# 17.428571428571427
# GunningFog score for Sentence:The Japanese economy is growing at 0.8 percent, yet it is at full employment.
# 8.457142857142857
# GunningFog score for Sentence:According to my research, the job picture has been particularly strong in Germany, Japan and South Korea — the industrial countries that employ the most robots .
# 14.8
# GunningFog score for Sentence:True, robots do represent a new obstacle for some poorer nations, namely those few that do not suffer from population decline.
# 14.114285714285714
# GunningFog score for Sentence:In the postwar era, countries like China escaped poverty by moving a rising young population off the farm and into more productive jobs in factories.
# 14.8
# GunningFog score for Sentence:Indeed, it was unusual for any country to sustain rapid growth unless the working-age population was increasing faster than 2 percent a year.
# 12.933333333333332
# GunningFog score for Sentence:My analysis shows that, in the 1980s, 17 of the 20 largest emerging economies had a working-age population expanding that fast, according to my research, but now there are only two: Nigeria and Saudi Arabia.
# 18.844444444444445
# GunningFog score for Sentence:And they will have a hard time moving a large segment of their young populations into industrial jobs, given that they now have to compete with robotic manufacturing elsewhere.
# 15.73793103448276
# GunningFog score for Sentence:Yet for the rising number of countries facing population decline, the effort to lift the labor force has begun.
# 9.705263157894738
# GunningFog score for Sentence:Starting in the 1980s, led by Singapore, nations from Chile to Australia have offered baby bonuses for women to have more children, but many have found that these bonuses are ineffective in the face of stronger cultural forces, including the desire of many women to pursue a career before having children.
# 22.75294117647059
# GunningFog score for Sentence:Others have tried with some success to boost the workforce directly by raising the retirement age, offering women incentives to join or return to the labor force after having kids, and opening doors to immigrant workers.
# 18.844444444444445
# GunningFog score for Sentence:The simple math, however, shows that particularly in rapidly aging, conservative societies such as Japan and Germany, none of these groups has the potential to make up for coming declines in the working-age population.
# 19.714285714285715
# GunningFog score for Sentence:Germany decided to admit roughly 1 million refugees in 2015, in part for economic reasons, but the resulting controversy has reduced the flow.
# 12.678260869565218
# GunningFog score for Sentence:Germany would have to admit 1.5 million each year through 2030 to fully offset the economic impact of its aging population.
# 10.304761904761905
# GunningFog score for Sentence:Japan, which on average admits fewer than 70,000 immigrants per year, would have to admit 1 million annually.
# 13.866666666666667
# GunningFog score for Sentence:Given the widespread political backlash against immigration, increases this large are unlikely.
# 11.466666666666667
# GunningFog score for Sentence:So far, robots are drawing comparatively little populist fire, perhaps in part because their numbers are still quite low.
# 9.705263157894738
# GunningFog score for Sentence:Worldwide, the industrial labor force includes about 320 million humans, compared with just 1.6 million robots.
# 8.9
# GunningFog score for Sentence:That’s a huge gap, even counting the superior strength and speed of the robots.
# 8.457142857142857
# GunningFog score for Sentence:And most of them fall in the category of unintelligent machines, committed to a single task such as turning a bolt or painting a car door.
# 15.015384615384617
# GunningFog score for Sentence:Nearly half of them work in the auto industry, which is still the largest employer (of humans) in the United States.
# 10.304761904761905
# GunningFog score for Sentence:In the future, economists may start counting robots the way they now count gains in the working-age population, as a driver of growth.
# 12.933333333333332
# GunningFog score for Sentence:For much of the world, robots will stand alongside immigrants, women and the elderly as a fourth pool of labor.
# 10.0
# GunningFog score for Sentence:Whether by design or accident, many of the countries with the most rapidly aging populations already have the most robots.
# 12.0
# GunningFog score for Sentence:According to the International Federation of Robotics, the nations with the highest density of industrial robots include South Korea, with 531 per 10,000 employees, Japan with 305 and Germany with 301.
# 18.851612903225806
# GunningFog score for Sentence:The United States ranks eighth with 176.
# 2.8000000000000003
# GunningFog score for Sentence:China is well behind with only 49, but on the bright side — arguably — it had the world’s fastest-growing robot population.
# 10.304761904761905
# GunningFog score for Sentence:Today, population trends are the most powerful force shaping the rise and fall of nations, the starting point of any discussion about an economy’s prospects.
# 14.8
# GunningFog score for Sentence:Most of the world is graying fast, and the economic answer to aging will be all hands on deck, no matter what they’re made of.
# 10.0
# GunningFog score for Sentence:Researchers describe the ‘emotional chatting machine’ as a first attempt at the problem of creating machines that can fully understand user emotion
#
#
# An “emotional chatting machine” has been developed by scientists, signalling the approach of an era in which human-robot interactions are seamless and go beyond the purely functional.
# 25.6
# GunningFog score for Sentence:The chatbot, developed by a Chinese team, is seen as a significant step towards the goal of developing emotionally sophisticated robots.
# 17.923809523809524
# GunningFog score for Sentence:The ECM, as it is known for short, was able to produce factually coherent answers whilst also imbuing its conversation with emotions such as happiness, sadness or disgust.
# 18.342857142857145
# GunningFog score for Sentence:Prof Björn Schuller, a computer scientist at Imperial College London who was not involved in the latest advance, described the work as “an important step” towards personal assistants that could read the emotional undercurrent of a conversation and respond with something akin to empathy.
# 23.963636363636365
# GunningFog score for Sentence:“This will be the next generation of intelligence to be met in daily experience, sooner rather than later,” he said.
# 14.0
# GunningFog score for Sentence:The paper found that 61% of humans who tested the machine favoured the emotional versions to the neutral chatbot.
# 7.6000000000000005
# GunningFog score for Sentence:Similar results have been found in so-called “Wizard of Oz” studies in which a human typing responses masquerades as advanced AI.
# 12.436363636363637
# GunningFog score for Sentence:“It is not a question whether they are desirable – they clearly are – but in which applications they make sense and where they don’t,” said Schuller.
# 13.200000000000001
# GunningFog score for Sentence:Minlie Huang, a computer scientist at Tsinghua University, Beijing and co-author, said: “We’re still far away from a machine that can fully understand the user’s emotion.
# 13.476923076923079
# GunningFog score for Sentence:This is just the first attempt at this problem.”
#
#
#
#
#
#
# Huang and colleagues started by creating an “emotion classifying” algorithm that learned to detect emotion from 23,000 posts taken from the Chinese social media site Weibo.
# 11.571428571428573
# GunningFog score for Sentence:The posts had been manually classified by humans as sad, happy and so on.
# 11.314285714285715
# GunningFog score for Sentence:The emotion classifier was then used to tag millions of social media interactions according to emotional content.
# 13.858823529411765
# GunningFog score for Sentence:This huge dataset served as a training ground for the chatbot to learn both how to answer questions and how to express emotion.
# 9.200000000000001
# GunningFog score for Sentence:The resulting program could be switched into five possible modes – happy, sad, angry, disgusted, liking – depending on the user’s preference.
# 16.0
# GunningFog score for Sentence:In one example conversation a user typed in: “Worst day ever.
# 11.672727272727274
# GunningFog score for Sentence:I arrived late because of the traffic.”
#
#
# In neutral mode, the chatbot droned: “You were late”.
# 3.2
# GunningFog score for Sentence:Alternative responses were: “Sometimes life just sucks!” (disgust mode), “I am always here to support you” (liking) or “Keep smiling!
# 6.0
# GunningFog score for Sentence:Things will get better” (happy – or, some might say, annoyingly chipper).
# 8.036363636363637
# GunningFog score for Sentence:In the future, the team predict the software could also learn the appropriate emotion to express at a given time.
# 10.0
# GunningFog score for Sentence:“It could be mostly empathic,” said Huang, adding that a challenge would be to avoid the chatbot reinforcing negative feelings such as rage.
# 12.678260869565218
# GunningFog score for Sentence:Until recently chatbots were widely regarded as a sideshow to more serious attempts at tackling machine intelligence.
# 11.505882352941178
# GunningFog score for Sentence:A chatbot known as Eugene Goostman managed to convince some judges they were talking to a human – but only by posing as a 13-year old Ukrainian boy with a limited grasp of English.
# 13.600000000000001
# GunningFog score for Sentence:Microsoft’s disastrous chatbot Tay was supposed to learn to chat from Twitter interactions, but was terminated after becoming a genocide-supporting Nazi less than 24 hours after being let loose on the internet.
# 20.472727272727276
# GunningFog score for Sentence:The latest study shows that chatbots, driven by a machine learning approach, are starting to make significant headway.
# 9.422222222222222
# GunningFog score for Sentence:Sandra Wachter, a computer scientist at the Oxford Internet Institute, said that in future such algorithms are likely to be personalised.
# 17.923809523809524
# GunningFog score for Sentence:“Some of us prefer a tough-love pep talk, others prefer someone to rant with,” she said.
# 6.800000000000001
# GunningFog score for Sentence:“Humans often struggle with appropriate responses because of the complexity of emotions, so building technologies that could decipher accurately our ‘emotional code’ would be very impressive.”
#
#
# As the stilted computer interactions of today are replaced by something approaching friendly chit-chat, new risks could be encountered.
# 17.895652173913046
# GunningFog score for Sentence:One concern is the potential for technology designed to seduce the user into sharing sensitive personal data.
# 13.858823529411765
# GunningFog score for Sentence:“It could be that children share insights with their ‘artificial friends’ and this data might be stored,” said Wachter.
# 9.705263157894738
# GunningFog score for Sentence:“What if we were to find out that people are more likely to buy more products when they are angry, sad, or bored?
# 9.200000000000001
# GunningFog score for Sentence:The ability to detect these emotions and successfully manipulate them could be a very interesting tool for companies.”
#
#
# There is also the potential for users to become emotionally dependent, or even romantically involved, with their computers.
# 17.2
# GunningFog score for Sentence:“However, there is also a huge potential for good, such as existing software to teach children on the autism spectrum [about] emotional and social interaction,” said Schuller.
# 15.244444444444447
# GunningFog score for Sentence:“One has to carefully balance benefits and risks and ensure the best exploitation.”
# 11.353846153846156

# %%
df = pd.read_csv('ted.csv')
df.head()
# Out:
#                                           transcript  \
# 0  We're going to talk — my — a new lecture, just...
# 1  This is a representation of your brain, and yo...
# 2  It's a great honor today to share with you The...
# 3  My passions are music, technology and making t...
# 4  It used to be that if you wanted to get a comp...
#
#                                                  url
# 0  https://www.ted.com/talks/al_seckel_says_our_b...
# 1  https://www.ted.com/talks/aaron_o_connell_maki...
# 2  https://www.ted.com/talks/carter_emmart_demos_...
# 3  https://www.ted.com/talks/jared_ficklin_new_wa...
# 4  https://www.ted.com/talks/jeremy_howard_the_wo...

# %%
nlp = spacy.load('en_core_web_sm')
stopwords = ENGLISH_STOP_WORDS
def preprocess(text):
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc]
    lemmaa = [lemma for lemma in tokens if lemma.isalpha() or lemma not in stopwords]
    return ' '.join(lemmaa)

# %%
df['preprocssed-transcript'] = df['transcript'].apply(preprocess)

# %%
df
# Out:
#                                             transcript  \
# 0    We're going to talk — my — a new lecture, just...
# 1    This is a representation of your brain, and yo...
# 2    It's a great honor today to share with you The...
# 3    My passions are music, technology and making t...
# 4    It used to be that if you wanted to get a comp...
# ..                                                 ...
# 495  Today I'm going to unpack for you three exampl...
# 496  Both myself and my brother belong to the under...
# 497  John Hockenberry: It's great to be here with y...
# 498  What you're doing, right now, at this very mom...
# 499  We've got a real problem with math education r...
#
#                                                    url  \
# 0    https://www.ted.com/talks/al_seckel_says_our_b...
# 1    https://www.ted.com/talks/aaron_o_connell_maki...
# 2    https://www.ted.com/talks/carter_emmart_demos_...
# 3    https://www.ted.com/talks/jared_ficklin_new_wa...
# 4    https://www.ted.com/talks/jeremy_howard_the_wo...
# ..                                                 ...
# 495  https://www.ted.com/talks/john_hodgman_design_...
# 496  https://www.ted.com/talks/sheikha_al_mayassa_g...
# 497  https://www.ted.com/talks/tom_shannon_the_pain...
# 498  https://www.ted.com/talks/nilofer_merchant_got...
# 499  https://www.ted.com/talks/conrad_wolfram_teach...
#
#                                 preprocssed-transcript
# 0    we be go to talk — my — a new lecture , just f...
# 1    this be a representation of your brain , and y...
# 2    it be a great honor today to share with you th...
# 3    my passion be music , technology and make thin...
# 4    it use to be that if you want to get a compute...
# ..                                                 ...
# 495  today I be go to unpack for you three example ...
# 496  both myself and my brother belong to the under...
# 497  John Hockenberry : it be great to be here with...
# 498  what you be do , right now , at this very mome...
# 499  we 've get a real problem with math education ...
#
# [500 rows x 3 columns]
